# %%
#Take two numbers by the users
num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))
 #Display operation choices
print("Select operation:")

print("1.Add (+)")
print("2.Subtract (-)")
print("3.Multiply (*)")
print("4. (/)")
#Take user choice
choice = input("Enter your choice (1/2/3/4):")
#perform operation base on your choice
if choice == '1':
  result = num1 + num2
  print(f"{num1} + {num2} = {result}")
elif choice == '2':
  result = num1 - num2
  print(f"{num1} - {num2} = {result}")
elif choice == '3':
  result = num1 * num2
  print(f"{num1} * {num2} = {result}")
elif choice == '4':
  if num2 != 0:
    result = num1 / num2
    print(f"{num1} / {num2} = {result}")
  else:
    print("Error: Division by zero is not allowed.")
else:
  print("Invalid choice. Please select a valid operation (1/2/3/4).")
# Out:
# Enter first number:45
# Enter second number:6
# Select operation:
# 1.Add (+)
# 2.Subtract (-)
# 3.Multiply (*)
# 4. (/)
# Enter your choice (1/2/3/4):5
# Invalid choice. Please select a valid operation (1/2/3/4).

# %%
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))

print("Choose operation to perform:")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

choice = int(input("Enter choice(1/2/3/4)."))
if choice == 1:
  result = num1+num2
  print("result:", result)
elif choice == 2:
    result = num1-num2
    print("result:", result)
elif choice ==3:
    result = num1*num2
    print("result:", result)
elif choice == 4:
  if num2 != 0:

    result = num1/num2
    print("result:", result)
  else:
       print("Invalid input division by zero not allowed")
else:
  print("Invalid choice. please select the valid input from 1 to 4")
# Out:
# Enter first number:45
# Enter second number:5
# Choose operation to perform:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4).3
# result: 225.0
